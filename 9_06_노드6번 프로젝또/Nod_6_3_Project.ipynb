# %% [markdown]
# <a href="https://colab.research.google.com/github/Noruzzang/AIFFEL_QUEST_cr/blob/master/Nod_6_3_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn

print(sklearn.__version__)


'''필요한 모듈 import하기'''


from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

'''데이터 준비'''

cancer = load_breast_cancer()  # load_breast_cancer 메서드를 사용합니다.

'''데이터 이해하기'''

X = cancer.data  # Feature Data 지정하기
y = cancer.target  # Label 데이터 지정하기
target_names = cancer.target_names
print("Target Names:", target_names) # Target Names 출력하기

df = pd.DataFrame(X, columns=cancer.feature_names)
description = df.describe()  # 데이터 Describe 해 보기
print(description)

'''모델 학습과 테스트용 문제지와 정답지를 준비해 봅시다.'''

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=72)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)



'''다양한 모델로 학습시켜보기'''

# Decision Tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))


# Random Forest
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))


# SVM
svm = SVC()
svm.fit(X_train_scaled, y_train)
y_pred_svm = svm.predict(X_test_scaled)
print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))


# SGD Classifier
sgd = SGDClassifier()
sgd.fit(X_train_scaled, y_train)
y_pred_sgd = sgd.predict(X_test_scaled)
print("SGD Classifier Accuracy:", accuracy_score(y_test, y_pred_sgd))


# Logistic Regression
lr = LogisticRegression(max_iter=1000)  # max_iter를 늘려서 수렴 문제를 방지 (Thanks to Gemini and Chat GPT)
lr.fit(X_train_scaled, y_train)
y_pred_lr = lr.predict(X_test_scaled)
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
# Out:
# 1.3.2
# Target Names: ['malignant' 'benign']
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# ...

# %% [markdown]
# 1.3.2
# Target Names: ['malignant' 'benign']
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst radius  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        worst texture  worst perimeter   worst area  worst smoothness  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        worst compactness  worst concavity  worst concave points  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        worst symmetry  worst fractal dimension
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]
# X_train shape: (455, 30)
# X_test shape: (114, 30)
# y_train shape: (455,)
# y_test shape: (114,)
# Decision Tree Accuracy: 0.9210526315789473
# Random Forest Accuracy: 0.9736842105263158
# SVM Accuracy: 0.956140350877193
# SGD Classifier Accuracy: 0.9385964912280702
# Logistic Regression Accuracy: 0.9649122807017544
#
#
# 가장 높은 수치가 Random Forest Accuracy 이므로
# Random Forest Accuracy를 택하겠습니다.
